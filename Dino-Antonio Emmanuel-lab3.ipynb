# %% [markdown]
# ## 195718
# ## Diño
# ## 3 BS ITE

# %%
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}

def relationship_status(from_member, to_member):
    if from_member in social_graph[to_member]['following']:
            if to_member in social_graph[from_member]['following']:
                return 'friends'
            else :
                return 'followed by'
    elif to_member in social_graph[from_member]['following']:
        return 'following'
    else :
        return none
       
            
acc1 = input('Account 1:')
acc2 = input('Account 2:')
relationship_status(acc1, acc2)
# Out:
# Account 1:@jobenilagan
# Account 2:@joeilagan
# 'friends'

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]




def get_winner(board):
    winner = None
    row = [x for x in board]
    column = [x for x in zip(*board)]
    diagonal1 = [board[i][i] for i,v in enumerate(board)]
    diagonal2 = [board[2-i][i] for i,v in enumerate(board)]
    
    rowset0 = len(set(row[0]))
    rowset1 = len(set(row[1]))
    rowset2 = len(set(row[2]))
    
    columnset0 = len(set(column[0]))
    columnset1 = len(set(column[1]))
    columnset2 = len(set(column[2]))
    
    diagonalset1 = set(diagonal1)
    diagonalset2 = set(diagonal2)
            
    if rowset0 == 1:
        return row[0][0]
    elif rowset1 == 1:
        return row[1][0]
    elif rowset2 == 1:
        return row[2][0]
    elif columnset0 == 1:
        return column[0][0]
    elif columnset1 == 1:
        return column[1][0]
    elif columnset2 == 1:
        return column[2][0]
    elif len(diagonalset1) == 1:
        return diagonal1[0]
    elif len(diagonalset2) == 1:
        return diagonal2[0]
    else:
        return winner 
    
     
print(get_winner(board3))
# Out:
# O

# %%
locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     }
}

def eta(source,destination):
    if (source, destination) in legs:
        key = legs[(source, destination)]
        eta = key['travel_time_mins']
        return eta
    elif source == 'admu' and destination == 'upd':
        eta = 90
        return eta
    elif source == 'upd' and destination == 'dlsu':
        eta = 45
        return eta
    elif source == 'dlsu' and destination == 'admu':
        eta = 65
        return eta
    else : 
        return "Invalid destinations"
        

print('ETA:',eta('dlsu','admu'))
# Out:
# ETA: 65
